# %% [markdown]
# # Câu 1:

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
data = pd.read_csv('Ecommerce_Purchases.csv')
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data = data.loc[:, ['Job', 'Purchase Price']]
data
# Out:
#                                          Job  Purchase Price
# 0     Scientist, product/process development           98.14
# 1                          Drilling engineer           70.73
# 2                   Customer service manager            0.95
# 3                          Drilling engineer           78.04
# 4                                Fine artist           77.82
# ...                                      ...             ...
# 9995                              Printmaker           82.21
# 9996                         Energy engineer           25.63
# 9997                      Veterinary surgeon           83.98
# 9998                Local government officer           38.84
# 9999                  Embryologist, clinical           67.59
#
# [10000 rows x 2 columns]

# %%
data = data.groupby(['Job']).sum('Purchase Price').sort_values('Purchase Price', ascending=False)
data = data.head()
# Tạo lại cột 'Job' bằng cách đặt lại chỉ mục
data = data.reset_index()

# %%
#plot
colors = ['blue', 'green', 'red', 'purple', 'orange']
data.plot(x='Job', y='Purchase Price', kind='bar', color=colors)
plt.xlabel('Profession')
plt.ylabel('Total Purchase')
plt.title('Biểu đồ cột')
# Out:
# Text(0.5, 1.0, 'Biểu đồ cột')

# %% [markdown]
# # Câu 2:

# %%
data = pd.read_csv('Ecommerce_Purchases.csv')
data = data.loc[:, ['Job', 'Purchase Price']]
data = data.groupby(['Job']).mean('Purchase Price').sort_values('Purchase Price', ascending=False)
data = data.head()
# Tạo lại cột 'Job' bằng cách đặt lại chỉ mục
data = data.reset_index()

# %%
#plot
colors = ['blue', 'green', 'red', 'purple', 'orange']
data.plot(x='Job', y='Purchase Price', kind='bar', color=colors)
plt.xlabel('Profession')
plt.ylabel('AVG Purchase')
plt.title('Biểu đồ cột')
# Out:
# Text(0.5, 1.0, 'Biểu đồ cột')

# %% [markdown]
# # Câu 3:

# %%
data = pd.read_csv('Ecommerce_Purchases.csv')
data['Browser'] = data['Browser Info'].str.extract('([A-Za-z]+)/')
data1 = data.groupby(['Job', 'Browser']).agg({'Purchase Price': 'count'}).unstack().head()
# data = data.reset_index()
data1.plot(kind='bar')
# Out:
# <Axes: xlabel='Job'>

# %% [markdown]
# # Câu 6:

# %%
data = pd.read_csv('Ecommerce_Purchases.csv')
data['LOT2'] = data['Lot'].str.extract('([A-Za-z]+)')
data['LOT2'] = data['LOT2'].str.upper()
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
#plot
data = data.groupby(['LOT2']).sum('Purchase Price').sort_values('Purchase Price', ascending=False).head()
# data.plot(kind='bar')
data = data.reset_index()
colors = ['blue', 'green', 'red', 'purple', 'orange']
data.plot(x='LOT2', y='Purchase Price', kind='bar', color=colors)
# plt.xlabel('Profession')
# plt.ylabel('AVG Purchase')
# plt.title('Biểu đồ cột')
# Out:
# <Axes: xlabel='LOT2'>

# %%
#plot
data = data.groupby(['LOT2']).a\('Purchase Price').sort_values('Purchase Price', ascending=False).head()
# data.plot(kind='bar')
data = data.reset_index()
colors = ['blue', 'green', 'red', 'purple', 'orange']
data.plot(x='LOT2', y='Purchase Price', kind='bar', color=colors)
# plt.xlabel('Profession')
# plt.ylabel('AVG Purchase')
# plt.title('Biểu đồ cột')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #plot
# ----> 2 data = data.groupby(['LOT2']).count('Purchase Price').sort_values('Purchase Price', ascending=False).head()
#       3 # data.plot(kind='bar')
#       4 data = data.reset_index()
#
# TypeError: GroupBy.count() takes 1 positional argument but 2 were given
